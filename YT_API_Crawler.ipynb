# %%
import os
import json
import requests
from bs4 import BeautifulSoup
import re

# %%
class YtApiUtil:
    def __init__(self):
        current_path = current_path = os.getcwd()
        youtube_key_name = "youtube_key.json"
        data_path = current_path + "/" + youtube_key_name
        file = open(data_path)
        file_dict = json.load(file)
        self.API_key = file_dict["API_key"]
        
    def get_all_playlists(self, channel_id, page_token=""):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/playlists?part=contentDetails&part=snippet&part=id&channelId={channel_id}&maxResults=50&key={API_key}&pageToken={page_token}"
        resp = requests.get(url)
        
        return json.loads(resp.text)
    
    def get_all_playlist_items(self, playlist_id, page_token=""):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/playlistItems?part=snippet&part=contentDetails&maxResults=50&playlistId={playlist_id}&key={API_key}&pageToken={page_token}"
        resp = requests.get(url)
        
        return json.loads(resp.text)
    
    def get_video_info(self, video_id):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/videos?part=contentDetails&part=snippet&id={video_id}&key={API_key}"
        resp = requests.get(url)
        
        try:
            video_info = json.loads(resp.text)["items"][0]
        except:
            video_info = None
        
        return video_info
        
class YtApiCrawler(YtApiUtil):
    def __init__(self):
        print("===YtApiCrawler init ===")
        super().__init__()

    def fetch_data(self, url):
        print("===YtApiCrawler fetch_data ===")
        channel_id = url.replace("https://www.youtube.com/channel/","")
        playlists = []
        page_token = ""
        has_next_page = True
        while has_next_page:
            all_playlists = self.get_all_playlists(channel_id, page_token)
            playlists += all_playlists["items"]
            if "nextPageToken" in all_playlists:
                page_token = all_playlists["nextPageToken"]
            else:
                has_next_page = False

        playlist_list = []
        for item in playlists:
            channel_id = item["snippet"]["channelId"]
            channel_name = item["snippet"]["channelTitle"]
            channel_url = url
            playlist_id = item["id"]
            playlist_title = item["snippet"]["title"]

            data = {
                "channel_id": channel_id,
                "channel_name": channel_name,
                "channel_url": channel_url,
                "playlist_id": playlist_id,
                "playlist_title": playlist_title,
                "video_items": []
            }

            playlist_list.append(data)

        playlist_items_list = []
        for playlist_dict in playlist_list:
            playlist_id = playlist_dict["playlist_id"]
            page_token = ""
            has_next_page = True
            while has_next_page:
                playlist_items = self.get_all_playlist_items(playlist_id, page_token)
                playlist_dict["video_items"] += playlist_items["items"]
                if "nextPageToken" in playlist_items:
                    page_token = playlist_items["nextPageToken"]
                else:
                    has_next_page = False
            playlist_items_list.append(playlist_dict)

        return playlist_items_list

    def get_data_json(self, playlist_items_list):
        data_json = []
        for playlist_dict in playlist_items_list:
            for item in playlist_dict["video_items"]:
                video_id = item["snippet"]["resourceId"]["videoId"]
                video_info = self.get_video_info(video_id)
                if video_info:
                    video_url = f"https://www.youtube.com/watch?v={video_id}"
                    published = item["snippet"]["publishedAt"]
                    title = item["snippet"]["title"]
                    description = item["snippet"]["description"]
                    playlist_position = item["snippet"]["position"]
                    
                    if "standard" in item["snippet"]["thumbnails"]:
                        img_link = item["snippet"]["thumbnails"]["standard"]["url"] 
                    else: 
                        img_link = ""

                    if "tags" in video_info["snippet"]:
                        tag_list = video_info["snippet"]["tags"]
                    else:
                        tag_list = []

                    channel_id = playlist_dict["channel_id"]
                    channel_url = playlist_dict["channel_url"]
                    channel_name = playlist_dict["channel_name"]
                    playlist_id = playlist_dict["playlist_id"]
                    playlist_title = playlist_dict["playlist_title"]
                    
                    data = {
                        "channel_id": channel_id,
                        "channel_url": channel_url,
                        "channel_name": channel_name,
                        "video_id": video_id,
                        "video_url": video_url,
                        "published": published,
                        "title": title,
                        "img_link": img_link,
                        "description": description,
                        "tag_list": tag_list,
                        "playlist_id": playlist_id,
                        "playlist_title": playlist_title,
                        "playlist_position": playlist_position
                    }
                    data_json.append(data)
                    print(data)
        
        return data_json

# %%
crawler = YtApiCrawler()
url = "https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ"
data = crawler.fetch_data(url)
# data_json = crawler.get_data_json(data)
# Out:
# ===YtApiCrawler init ===
# ===YtApiCrawler fetch_data ===
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#  'channel_name': '均一教育平台(軟體組)',
#  'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#  'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#  'playlist_title': '微分享(公開版)',
#  'video_items': [{'kind': 'youtube#playlistItem',
#    'etag': '-5cKJWFG2BGP-R74yFMXEzX1rRU',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS4wMTcyMDhGQUE4NTIzM0Y5',
#    'snippet': {'publishedAt': '2022-05-10T05:29:41Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】Mob Programming',
#     'description': '・分享者：沈家緯\n・分享內容：Mob Programming 大家一起開發\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JLkYTc6U-g0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JLkYTc6U-g0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JLkYTc6U-g0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/JLkYTc6U-g0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/JLkYTc6U-g0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 0,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'JLkYTc6U-g0'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'JLkYTc6U-g0',
#     'videoPublishedAt': '2022-02-18T06:48:07Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '5vcmmY5dl6B8mYsQKz-xd-G4MTQ',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS41MjE1MkI0OTQ2QzJGNzNG',
#    'snippet': {'publishedAt': '2022-05-10T05:30:02Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】工程師的浪漫：寫程式破解日文版 wordle',
#     'description': '・分享者：軍樂（前端實習生）\n・分享內容：寫程式破解日文版 wordle\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E_x4al5INak/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E_x4al5INak/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E_x4al5INak/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/E_x4al5INak/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/E_x4al5INak/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 1,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'E_x4al5INak'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'E_x4al5INak',
#     'videoPublishedAt': '2022-03-02T05:00:25Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'v5mjEFUS5LiDVOzOiOyk_ROf5DE',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS4wOTA3OTZBNzVEMTUzOTMy',
#    'snippet': {'publishedAt': '2022-05-10T05:30:02Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】工程師的浪漫：寫程式破解 Nerdle game',
#     'description': '・分享者：先祐\n・分享內容：寫程式破解 Nerdle game\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-ImSbzXWMA4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-ImSbzXWMA4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-ImSbzXWMA4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-ImSbzXWMA4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-ImSbzXWMA4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 2,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '-ImSbzXWMA4'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': '-ImSbzXWMA4',
#     'videoPublishedAt': '2022-03-01T04:42:25Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'J8S-Gqcdq8M74KzIdtdFMGNI3BU',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS4xMkVGQjNCMUM1N0RFNEUx',
#    'snippet': {'publishedAt': '2022-05-10T05:30:21Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】平行化運算(或團隊合作效果)的參考指標：速度/效率/成本間取捨的藝術',
#     'description': '・分享者：雲行（軟體實習生）\n・分享內容：平行化運算(團隊合作效果)的參考指標：速度/效率/成本間取捨的藝術\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zqEM-HmAhvk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zqEM-HmAhvk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zqEM-HmAhvk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zqEM-HmAhvk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zqEM-HmAhvk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 3,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'zqEM-HmAhvk'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'zqEM-HmAhvk',
#     'videoPublishedAt': '2022-03-04T05:08:08Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'hzBsywodsrdNPGVWzLCKGbZOJSo',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS41MzJCQjBCNDIyRkJDN0VD',
#    'snippet': {'publishedAt': '2022-05-10T05:30:46Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】Web(World Wide Web)的起源：為什麼 Tim Berner-lee 想要設計Web？',
#     'description': '・分享者：Nissen\n・分享內容：Web的起源：為什麼會有人想要設計Web？\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T3b8btc6zwM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/T3b8btc6zwM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/T3b8btc6zwM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/T3b8btc6zwM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/T3b8btc6zwM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 4,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'T3b8btc6zwM'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'T3b8btc6zwM',
#     'videoPublishedAt': '2022-04-15T05:24:40Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'xjiQX5fopoAxeGg2Mql6ZDGwQh4',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS5DQUNERDQ2NkIzRUQxNTY1',
#    'snippet': {'publishedAt': '2022-05-10T05:31:05Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【書籍分享】資料密集型應用系統設計 Ch1',
#     'description': '・分享者：Nissen\n・分享內容：資料密集型應用系統設計 Ch1\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gZQjUrFW948/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gZQjUrFW948/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gZQjUrFW948/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/gZQjUrFW948/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/gZQjUrFW948/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 5,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'gZQjUrFW948'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'gZQjUrFW948',
#     'videoPublishedAt': '2022-05-03T05:10:37Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ibprSraG9pBrosHtfPXFfl6Bduw',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS45NDk1REZENzhEMzU5MDQz',
#    'snippet': {'publishedAt': '2022-05-10T05:31:19Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】Monorepo 的架構設計',
#     'description': '・分享者：家緯\n・分享內容：軟體工程師\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 6,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '_v1Rv1oIEWk'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': '_v1Rv1oIEWk',
#     'videoPublishedAt': '2022-03-29T04:46:53Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '6AnBPbndLrSdmJm34dgDGXsyjIM',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS5GNjNDRDREMDQxOThCMDQ2',
#    'snippet': {'publishedAt': '2022-05-10T05:31:43Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】區塊鏈遊戲',
#     'description': '・分享者：雲行（軟體QA實習生）\n・分享內容：區塊鏈遊戲\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vtg0oqllKtI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vtg0oqllKtI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vtg0oqllKtI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vtg0oqllKtI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vtg0oqllKtI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 7,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'vtg0oqllKtI'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'vtg0oqllKtI',
#     'videoPublishedAt': '2022-01-25T04:56:47Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'byDPjXYaRmEzKShXazHAlyKqlp0',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS40NzZCMERDMjVEN0RFRThB',
#    'snippet': {'publishedAt': '2022-05-10T05:32:05Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【前端小知識】CSS : image-rendering',
#     'description': '・分享者：軍樂\n・分享內容：什麼是css 的 image-rendering ？\n----------------------------------------------------------------------------------------------------\n「微分享」是均一軟體組每日的都有的 15min 技術分享（一個不希望大家特別準備/低成本的技術分享）',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 8,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '8DcJxx5jpFQ'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': '8DcJxx5jpFQ',
#     'videoPublishedAt': '2021-12-22T07:45:56Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'lu203QRZ7st0QjQh812yRn5UXJ0',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS5EMEEwRUY5M0RDRTU3NDJC',
#    'snippet': {'publishedAt': '2022-05-10T05:32:23Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【No code軟體】表單軟體 Tally 和 Getbutton',
#     'description': '・分享者：毓賢（產品經理）\n・分享內容：表單軟體 Tally 和 Getbutton\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7lMtei_3Cp4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7lMtei_3Cp4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7lMtei_3Cp4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7lMtei_3Cp4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7lMtei_3Cp4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 9,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '7lMtei_3Cp4'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': '7lMtei_3Cp4',
#     'videoPublishedAt': '2022-05-05T06:22:44Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'DPlSYi-BnPI_9xPvIP3xahEIBfA',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS45ODRDNTg0QjA4NkFBNkQy',
#    'snippet': {'publishedAt': '2022-05-10T05:32:57Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【好物分享】Terminal Warp：一個終於比較正常的終端機',
#     'description': '・分享者：Nissen\n・分享內容：一個終於比較正常的終端機（Terminal） Warp\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/\n・Warp：https://www.warp.dev/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d3O3ju1l6vI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/d3O3ju1l6vI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/d3O3ju1l6vI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/d3O3ju1l6vI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/d3O3ju1l6vI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 10,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'd3O3ju1l6vI'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'd3O3ju1l6vI',
#     'videoPublishedAt': '2021-12-23T05:11:18Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'qQF4IvXrj0zRTZVXh9b4V-zPBtg',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS4zMDg5MkQ5MEVDMEM1NTg2',
#    'snippet': {'publishedAt': '2022-05-10T05:33:10Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】地圖資訊交換格式(GeoJson)',
#     'description': '・分享者：Vincent（實習生）\n・分享內容：地圖資訊是如何儲存的？\n----------------------------------------------------------------------------------------------------\n・微分享：是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・均一：一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sNDoLXorAKg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sNDoLXorAKg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sNDoLXorAKg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sNDoLXorAKg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sNDoLXorAKg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 11,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'sNDoLXorAKg'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'sNDoLXorAKg',
#     'videoPublishedAt': '2021-12-22T12:38:39Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '5Vr-71ba_kGHY6EoaUfQddqjE3Y',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS41Mzk2QTAxMTkzNDk4MDhF',
#    'snippet': {'publishedAt': '2022-05-10T05:33:23Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【入門介紹】機器學習',
#     'description': '・分享者：軍樂\n・分享內容：機器學習介紹＆應用\n----------------------------------------------------------------------------------------------------\n「微分享」是均一軟體組每日的都有的 15min 技術分享（一個不希望大家特別準備/低成本的技術分享）"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 12,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Fd6AMP0YU3k'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'Fd6AMP0YU3k',
#     'videoPublishedAt': '2021-12-22T12:23:17Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'XzeUtg6D0KyVYOS62j539zM3DRc',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS5EQUE1NTFDRjcwMDg0NEMz',
#    'snippet': {'publishedAt': '2022-05-10T05:37:24Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】管理思維：Efficiency and effectiveness',
#     'description': '・分享者：家緯（軟體工程師）\n・分享內容：管理思維：Efficiency and effectiveness\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FFFFzEUdsX8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FFFFzEUdsX8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FFFFzEUdsX8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/FFFFzEUdsX8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/FFFFzEUdsX8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 13,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'FFFFzEUdsX8'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'FFFFzEUdsX8',
#     'videoPublishedAt': '2022-03-11T05:12:49Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '6gJDVz82jBjSi2SzAzyeMrW3Kso',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS41QTY1Q0UxMTVCODczNThE',
#    'snippet': {'publishedAt': '2022-05-10T05:39:46Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【後端】Python import 系統',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CMIvqyokTbw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CMIvqyokTbw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CMIvqyokTbw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/CMIvqyokTbw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/CMIvqyokTbw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 14,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'CMIvqyokTbw'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'CMIvqyokTbw',
#     'videoPublishedAt': '2021-12-03T10:49:06Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'QI1WU0LgMwkKE5828yz7uD9n1yM',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS4yMUQyQTQzMjRDNzMyQTMy',
#    'snippet': {'publishedAt': '2022-05-10T05:39:46Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】Python 虛擬環境管理 Anaconda',
#     'description': '・分享者：雲行（軟體QA實習生）\n・分享內容：Anaconda\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FRgC0mKiu9c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FRgC0mKiu9c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FRgC0mKiu9c/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/FRgC0mKiu9c/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/FRgC0mKiu9c/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 15,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'FRgC0mKiu9c'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'FRgC0mKiu9c',
#     'videoPublishedAt': '2022-04-18T05:09:11Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'iLX6e_B-zjIZCNm3jJQZMMsJs_k',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS45RTgxNDRBMzUwRjQ0MDhC',
#    'snippet': {'publishedAt': '2022-05-10T05:42:37Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【微分享】Pyenv 是怎麼運作的？',
#     'description': '・分享者：Vincent（實習生）\n・分享內容：Pyenv 是怎麼運作的？\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tVeXZ7TRzwk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tVeXZ7TRzwk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tVeXZ7TRzwk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 16,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'tVeXZ7TRzwk'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'tVeXZ7TRzwk',
#     'videoPublishedAt': '2022-01-10T05:04:45Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'z-T-e6N8fk5pvRYuSWqyuGzYpDE',
#    'id': 'UEx0S29CV1RrVmtUYzZJLVdyTEREY0NnTXkyZ2RYTGFRWS5ENDU4Q0M4RDExNzM1Mjcy',
#    'snippet': {'publishedAt': '2022-05-16T04:54:36Z',
#     'channelId': 'UCLNBEt_42kYuX7fgZiubgXQ',
#     'title': '【刷題】Two Sum 變化題',
#     'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L-Pv7uROcac/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L-Pv7uROcac/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L-Pv7uROcac/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L-Pv7uROcac/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '均一教育平台(軟體組)',
#     'playlistId': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#     'position': 17,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'L-Pv7uROcac'},
#     'videoOwnerChannelTitle': '均一教育平台(軟體組)',
#     'videoOwnerChannelId': 'UCLNBEt_42kYuX7fgZiubgXQ'},
#    'contentDetails': {'videoId': 'L-Pv7uROcac',
#     'videoPublishedAt': '2022-05-16T04:53:59Z'}}]}

# %% [markdown]
# ## data["items"][0]["snippet"]["thumbnails"]["medium"]["url"]

# %%
item = data["items"][0]
video_id = item["snippet"]["resourceId"]["videoId"]
video_url = f"https://www.youtube.com/watch?v={video_id}"
published = item["snippet"]["publishedAt"]
title = item["snippet"]["title"]
img_link = item["snippet"]["thumbnails"]["maxres"]["url"]
description = item["snippet"]["description"]
playlist_position = item["snippet"]["position"]

playlist_position
# Out:
# 0

# %%
# get all playlists in channel
GET https://youtube.googleapis.com/youtube/v3/playlists?part=contentDetails&part=snippet&part=id&channelId=UCyDIP-h6xNBAiXITkbvubhA&maxResults=50&key=[YOUR_API_KEY] HTTP/1.1
GET https://youtube.googleapis.com/youtube/v3/search?channelId=UCyDIP-h6xNBAiXITkbvubhA&pageToken=CAUQAA&key=[YOUR_API_KEY] HTTP/1.1

    
# get all playlistitems in playlist
GET https://youtube.googleapis.com/youtube/v3/playlistItems?part=snippet&part=contentDetails&maxResults=50&playlistId=PLI6pJZaOCtF1vPNVcsR6K31FbqZ2V6PVi&key=[YOUR_API_KEY] HTTP/1.1

# get video info by video_id
GET https://youtube.googleapis.com/youtube/v3/videos?part=contentDetails&part=snippet&id=aFx44mglAbs&maxResults=50&key=[YOUR_API_KEY] HTTP/1.1

    
# get all videos by channel_id
GET https://youtube.googleapis.com/youtube/v3/search?part=snippet&channelId={channelId}&key={API_KEY}

# %%
import os
import json
import requests
from bs4 import BeautifulSoup
import re

class YoutubeRequestsCrawler:
    def __init__(self):
        print("===crawler init ===")

    def get_yt_playlist_with_video(self, url, channel_name):
        resp = requests.get(url)
        data_soup = BeautifulSoup(resp.text, 'html.parser')
        video_title = data_soup.select_one('meta[name="title"]')["content"]
        query_url = f"https://www.youtube.com/results?sp=mAEB&search_query={video_title}+{channel_name}"
        resp = requests.get(query_url)
        data_soup = BeautifulSoup(resp.text, 'html.parser')
        data_soup_str = str(data_soup)
        
        
        try:
            playlist_pattern = r'{"playlistRenderer":{"playlistId":"(.*?)"'
            playlist_id = re.findall(playlist_pattern, data_soup_str)[0]
        except:
            playlist_id = ""
            
        if playlist_id:
            video_id = url.replace("https://www.youtube.com/watch?v=","")
            query_url = f"https://www.youtube.com/watch?v={video_id}&list={playlist_id}"
            resp = requests.get(query_url)
            data_soup = BeautifulSoup(resp.text, 'html.parser')
            data_soup_str = str(data_soup)
#             print(data_soup_str)
            index_pattern = f'"videoId":"{video_id}","playlistId":"{playlist_id}","index":(.\d*).*'
            playlist_position = re.findall(index_pattern, data_soup_str)[0]
            playlist_position = int(playlist_position) + 1
        else:
            playlist_position = ""

        data = {
            "playlist_id": playlist_id,
            "playlist_position": playlist_position
        }
        print(data)
        
        return data

# %%
crawler = YoutubeRequestsCrawler()
url = "https://www.youtube.com/watch?v=mYuinFT5wgs"
channel_name = "數感實驗室Numeracy Lab"
crawler.get_yt_playlist_with_video(url, channel_name)
# Out:
# ===crawler init ===
# {'playlist_id': 'PLzA1Q82AYGfbivssQveoOojDKG_TkBD3g', 'playlist_position': 7}
# {'playlist_id': 'PLzA1Q82AYGfbivssQveoOojDKG_TkBD3g', 'playlist_position': 7}
