# %%
import os
import json
import requests

# %%
class YtApiUtil:
    def __init__(self):
        current_path = current_path = os.getcwd()
        youtube_key_name = "youtube_key.json"
        data_path = current_path + "/" + youtube_key_name
        file = open(data_path)
        file_dict = json.load(file)
        self.API_key = file_dict["API_key"]
        
    def get_all_playlists(self, channel_id, page_token=""):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/playlists?part=contentDetails&part=snippet&part=id&channelId={channel_id}&maxResults=50&key={API_key}&pageToken={page_token}"
        resp = requests.get(url)
        
        return json.loads(resp.text)
    
    def get_all_playlist_items(self, playlist_id, page_token=""):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/playlistItems?part=snippet&part=contentDetails&maxResults=50&playlistId={playlist_id}&key={API_key}&pageToken={page_token}"
        resp = requests.get(url)
        
        return json.loads(resp.text)
    
    def get_video_info(self, video_id):
        API_key = self.API_key
        url = f"https://youtube.googleapis.com/youtube/v3/videos?part=contentDetails&part=snippet&id={video_id}&key={API_key}"
        resp = requests.get(url)
        
        try:
            video_info = json.loads(resp.text)["items"][0]
        except:
            video_info = None
        
        return video_info
        
class YtApiCrawler(YtApiUtil):
    def __init__(self):
        super().__init__()
    
    def fetch_data(self, url):
        print("===YtCrawlerInPlaylist fetch_data ===")
        channel_id = url.replace("https://www.youtube.com/channel/","")
        playlist_items = []
        page_token = ""
        has_next_page = True
        while has_next_page:
            data = self.get_all_playlists(channel_id, page_token)
            playlist_items += data["items"]
            if "nextPageToken" in data:
                page_token = data["nextPageToken"]
            else:
                has_next_page = False

        playlist_list = []
        for item in playlist_items:
            channel_id = item["snippet"]["channelId"]
            channel_title = item["snippet"]["channelTitle"]
            channel_url = url
            playlist_id = item["id"]
            playlist_title = item["snippet"]["title"]

            playlist_items = {
                "channel_id": channel_id,
                "channel_title": channel_title,
                "channel_url": channel_url,
                "playlist_id": playlist_id,
                "playlist_title": playlist_title,        
            }

            playlist_list.append(playlist_items)

        playlist_items_list = []
        for playlist_dict in playlist_list:
            playlist_id = playlist_dict["playlist_id"]

            page_token = ""
            has_next_page = True
            items = []
            while has_next_page:
                data = self.get_all_playlist_items(playlist_id, page_token)
                items += data["items"]
                if "nextPageToken" in data:
                    page_token = data["nextPageToken"]
                else:
                    has_next_page = False

            for item in items:
                video_id = item["snippet"]["resourceId"]["videoId"]
                video_info = self.get_video_info(video_id)
                if video_info:
                    video_url = f"https://www.youtube.com/watch?v={video_id}"
                    published = item["snippet"]["publishedAt"]
                    title = item["snippet"]["title"]
                    description = item["snippet"]["description"]
                    playlist_position = item["snippet"]["position"]
                    
                    if "standard" in item["snippet"]["thumbnails"]:
                        img_link = item["snippet"]["thumbnails"]["standard"]["url"] 
                    else: 
                        img_link = ""

                    if "tags" in video_info["snippet"]:
                        tags = video_info["snippet"]["tags"]
                    else:
                        tags = []

                    playlist_dict["video_id"] = video_id
                    playlist_dict["video_url"] = video_url
                    playlist_dict["published"] = published
                    playlist_dict["title"] = title
                    playlist_dict["img_link"] = img_link
                    playlist_dict["description"] = description
                    playlist_dict["playlist_position"] = playlist_position
                    playlist_dict["tags"] = tags
                    
                    playlist_items_list.append(playlist_dict)
                    
        return playlist_items_list
        
    def get_data_json(self, playlist_items_list):
        
        return playlist_items_list

# %%
crawler = YtApiCrawler()
url = "https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ"
crawler.fetch_data(url)
# Out:
# ===YtCrawlerInPlaylist fetch_data ===
# https://www.youtube.com/watch?v=JLkYTc6U-g0
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'JLkYTc6U-g0', 'video_url': 'https://www.youtube.com/watch?v=JLkYTc6U-g0', 'published': '2022-05-10T05:29:41Z', 'title': '【微分享】Mob Programming', 'img_link': 'https://i.ytimg.com/vi/JLkYTc6U-g0/sddefault.jpg', 'description': '・分享者：沈家緯\n・分享內容：Mob Programming 大家一起開發\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 0, 'tags': []}
# https://www.youtube.com/watch?v=E_x4al5INak
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'E_x4al5INak', 'video_url': 'https://www.youtube.com/watch?v=E_x4al5INak', 'published': '2022-05-10T05:30:02Z', 'title': '【微分享】工程師的浪漫：寫程式破解日文版 wordle', 'img_link': 'https://i.ytimg.com/vi/E_x4al5INak/sddefault.jpg', 'description': '・分享者：軍樂（前端實習生）\n・分享內容：寫程式破解日文版 wordle\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 1, 'tags': []}
# https://www.youtube.com/watch?v=-ImSbzXWMA4
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': '-ImSbzXWMA4', 'video_url': 'https://www.youtube.com/watch?v=-ImSbzXWMA4', 'published': '2022-05-10T05:30:02Z', 'title': '【微分享】工程師的浪漫：寫程式破解 Nerdle game', 'img_link': 'https://i.ytimg.com/vi/-ImSbzXWMA4/sddefault.jpg', 'description': '・分享者：先祐\n・分享內容：寫程式破解 Nerdle game\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 2, 'tags': []}
# https://www.youtube.com/watch?v=zqEM-HmAhvk
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'zqEM-HmAhvk', 'video_url': 'https://www.youtube.com/watch?v=zqEM-HmAhvk', 'published': '2022-05-10T05:30:21Z', 'title': '【微分享】平行化運算(或團隊合作效果)的參考指標：速度/效率/成本間取捨的藝術', 'img_link': 'https://i.ytimg.com/vi/zqEM-HmAhvk/sddefault.jpg', 'description': '・分享者：雲行（軟體實習生）\n・分享內容：平行化運算(團隊合作效果)的參考指標：速度/效率/成本間取捨的藝術\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 3, 'tags': []}
# https://www.youtube.com/watch?v=T3b8btc6zwM
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'T3b8btc6zwM', 'video_url': 'https://www.youtube.com/watch?v=T3b8btc6zwM', 'published': '2022-05-10T05:30:46Z', 'title': '【微分享】Web(World Wide Web)的起源：為什麼 Tim Berner-lee 想要設計Web？', 'img_link': 'https://i.ytimg.com/vi/T3b8btc6zwM/sddefault.jpg', 'description': '・分享者：Nissen\n・分享內容：Web的起源：為什麼會有人想要設計Web？\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 4, 'tags': []}
# https://www.youtube.com/watch?v=gZQjUrFW948
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'gZQjUrFW948', 'video_url': 'https://www.youtube.com/watch?v=gZQjUrFW948', 'published': '2022-05-10T05:31:05Z', 'title': '【書籍分享】資料密集型應用系統設計 Ch1', 'img_link': 'https://i.ytimg.com/vi/gZQjUrFW948/sddefault.jpg', 'description': '・分享者：Nissen\n・分享內容：資料密集型應用系統設計 Ch1\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 5, 'tags': []}
# https://www.youtube.com/watch?v=_v1Rv1oIEWk
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': '_v1Rv1oIEWk', 'video_url': 'https://www.youtube.com/watch?v=_v1Rv1oIEWk', 'published': '2022-05-10T05:31:19Z', 'title': '【微分享】Monorepo 的架構設計', 'img_link': 'https://i.ytimg.com/vi/_v1Rv1oIEWk/sddefault.jpg', 'description': '・分享者：家緯\n・分享內容：軟體工程師\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 6, 'tags': []}
# https://www.youtube.com/watch?v=vtg0oqllKtI
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'vtg0oqllKtI', 'video_url': 'https://www.youtube.com/watch?v=vtg0oqllKtI', 'published': '2022-05-10T05:31:43Z', 'title': '【微分享】區塊鏈遊戲', 'img_link': 'https://i.ytimg.com/vi/vtg0oqllKtI/sddefault.jpg', 'description': '・分享者：雲行（軟體QA實習生）\n・分享內容：區塊鏈遊戲\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/', 'playlist_position': 7, 'tags': []}
# https://www.youtube.com/watch?v=8DcJxx5jpFQ
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': '8DcJxx5jpFQ', 'video_url': 'https://www.youtube.com/watch?v=8DcJxx5jpFQ', 'published': '2022-05-10T05:32:05Z', 'title': '【前端小知識】CSS : image-rendering', 'img_link': 'https://i.ytimg.com/vi/8DcJxx5jpFQ/sddefault.jpg', 'description': '・分享者：軍樂\n・分享內容：什麼是css 的 image-rendering ？\n----------------------------------------------------------------------------------------------------\n「微分享」是均一軟體組每日的都有的 15min 技術分享（一個不希望大家特別準備/低成本的技術分享）', 'playlist_position': 8, 'tags': []}
# https://www.youtube.com/watch?v=7lMtei_3Cp4
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': '7lMtei_3Cp4', 'video_url': 'https://www.youtube.com/watch?v=7lMtei_3Cp4', 'published': '2022-05-10T05:32:23Z', 'title': '【No code軟體】表單軟體 Tally 和 Getbutton', 'img_link': 'https://i.ytimg.com/vi/7lMtei_3Cp4/sddefault.jpg', 'description': '・分享者：毓賢（產品經理）\n・分享內容：表單軟體 Tally 和 Getbutton\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 9, 'tags': []}
# https://www.youtube.com/watch?v=d3O3ju1l6vI
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'd3O3ju1l6vI', 'video_url': 'https://www.youtube.com/watch?v=d3O3ju1l6vI', 'published': '2022-05-10T05:32:57Z', 'title': '【好物分享】Terminal Warp：一個終於比較正常的終端機', 'img_link': 'https://i.ytimg.com/vi/d3O3ju1l6vI/sddefault.jpg', 'description': '・分享者：Nissen\n・分享內容：一個終於比較正常的終端機（Terminal） Warp\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/\n・Warp：https://www.warp.dev/', 'playlist_position': 10, 'tags': []}
# https://www.youtube.com/watch?v=sNDoLXorAKg
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'sNDoLXorAKg', 'video_url': 'https://www.youtube.com/watch?v=sNDoLXorAKg', 'published': '2022-05-10T05:33:10Z', 'title': '【微分享】地圖資訊交換格式(GeoJson)', 'img_link': 'https://i.ytimg.com/vi/sNDoLXorAKg/sddefault.jpg', 'description': '・分享者：Vincent（實習生）\n・分享內容：地圖資訊是如何儲存的？\n----------------------------------------------------------------------------------------------------\n・微分享：是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・均一：一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/', 'playlist_position': 11, 'tags': []}
# https://www.youtube.com/watch?v=Fd6AMP0YU3k
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'Fd6AMP0YU3k', 'video_url': 'https://www.youtube.com/watch?v=Fd6AMP0YU3k', 'published': '2022-05-10T05:33:23Z', 'title': '【入門介紹】機器學習', 'img_link': 'https://i.ytimg.com/vi/Fd6AMP0YU3k/sddefault.jpg', 'description': '・分享者：軍樂\n・分享內容：機器學習介紹＆應用\n----------------------------------------------------------------------------------------------------\n「微分享」是均一軟體組每日的都有的 15min 技術分享（一個不希望大家特別準備/低成本的技術分享）"', 'playlist_position': 12, 'tags': []}
# https://www.youtube.com/watch?v=FFFFzEUdsX8
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'FFFFzEUdsX8', 'video_url': 'https://www.youtube.com/watch?v=FFFFzEUdsX8', 'published': '2022-05-10T05:37:24Z', 'title': '【微分享】管理思維：Efficiency and effectiveness', 'img_link': 'https://i.ytimg.com/vi/FFFFzEUdsX8/sddefault.jpg', 'description': '・分享者：家緯（軟體工程師）\n・分享內容：管理思維：Efficiency and effectiveness\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 13, 'tags': []}
# https://www.youtube.com/watch?v=CMIvqyokTbw
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'CMIvqyokTbw', 'video_url': 'https://www.youtube.com/watch?v=CMIvqyokTbw', 'published': '2022-05-10T05:39:46Z', 'title': '【後端】Python import 系統', 'img_link': 'https://i.ytimg.com/vi/CMIvqyokTbw/sddefault.jpg', 'description': '', 'playlist_position': 14, 'tags': []}
# https://www.youtube.com/watch?v=FRgC0mKiu9c
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'FRgC0mKiu9c', 'video_url': 'https://www.youtube.com/watch?v=FRgC0mKiu9c', 'published': '2022-05-10T05:39:46Z', 'title': '【微分享】Python 虛擬環境管理 Anaconda', 'img_link': 'https://i.ytimg.com/vi/FRgC0mKiu9c/sddefault.jpg', 'description': '・分享者：雲行（軟體QA實習生）\n・分享內容：Anaconda\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/', 'playlist_position': 15, 'tags': []}
# https://www.youtube.com/watch?v=tVeXZ7TRzwk
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'tVeXZ7TRzwk', 'video_url': 'https://www.youtube.com/watch?v=tVeXZ7TRzwk', 'published': '2022-05-10T05:42:37Z', 'title': '【微分享】Pyenv 是怎麼運作的？', 'img_link': '', 'description': '・分享者：Vincent（實習生）\n・分享內容：Pyenv 是怎麼運作的？\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 16, 'tags': []}
# https://www.youtube.com/watch?v=L-Pv7uROcac
# -----
# {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ', 'channel_title': '均一教育平台(軟體組)', 'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ', 'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY', 'playlist_title': '微分享(公開版)', 'video_id': 'L-Pv7uROcac', 'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac', 'published': '2022-05-16T04:54:36Z', 'title': '【刷題】Two Sum 變化題', 'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg', 'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"', 'playlist_position': 17, 'tags': []}
# [{'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []},
#  {'channel_id': 'UCLNBEt_42kYuX7fgZiubgXQ',
#   'channel_title': '均一教育平台(軟體組)',
#   'channel_url': 'https://www.youtube.com/channel/UCLNBEt_42kYuX7fgZiubgXQ',
#   'playlist_id': 'PLtKoBWTkVkTc6I-WrLDDcCgMy2gdXLaQY',
#   'playlist_title': '微分享(公開版)',
#   'video_id': 'L-Pv7uROcac',
#   'video_url': 'https://www.youtube.com/watch?v=L-Pv7uROcac',
#   'published': '2022-05-16T04:54:36Z',
#   'title': '【刷題】Two Sum 變化題',
#   'img_link': 'https://i.ytimg.com/vi/L-Pv7uROcac/sddefault.jpg',
#   'description': '・分享者：Vincent（後端軟體實習生）\n・分享內容：Two Sum\n・來源：均一微分享\n----------------------------------------------------------------------------------------------------\n・「微分享」是均一軟體組每天的都有的 15min 技術分享（一個不希望大家特別準備/隨意/低成本的技術分享）\n・「均一」一個希望幫助孩子成為終身學習者的線上學習平台 https://www.junyiacademy.org/"',
#   'playlist_position': 17,
#   'tags': []}]

# %%
data["items"][0]["snippet"]["thumbnails"]["medium"]["url"]
# Out:
# 'https://i.ytimg.com/vi/RbEo4fkvafQ/mqdefault.jpg'

# %%
item = data["items"][0]
video_id = item["snippet"]["resourceId"]["videoId"]
video_url = f"https://www.youtube.com/watch?v={video_id}"
published = item["snippet"]["publishedAt"]
title = item["snippet"]["title"]
img_link = item["snippet"]["thumbnails"]["maxres"]["url"]
description = item["snippet"]["description"]
playlist_position = item["snippet"]["position"]

playlist_position
# Out:
# 0

# %%
# get all playlists in channel
GET https://youtube.googleapis.com/youtube/v3/playlists?part=contentDetails&part=snippet&part=id&channelId=UCyDIP-h6xNBAiXITkbvubhA&maxResults=50&key=[YOUR_API_KEY] HTTP/1.1
GET https://youtube.googleapis.com/youtube/v3/search?channelId=UCyDIP-h6xNBAiXITkbvubhA&pageToken=CAUQAA&key=[YOUR_API_KEY] HTTP/1.1

    
# get all playlistitems in playlist
GET https://youtube.googleapis.com/youtube/v3/playlistItems?part=snippet&part=contentDetails&maxResults=50&playlistId=PLI6pJZaOCtF1vPNVcsR6K31FbqZ2V6PVi&key=[YOUR_API_KEY] HTTP/1.1

# get video info by video_id
GET https://youtube.googleapis.com/youtube/v3/videos?part=contentDetails&part=snippet&id=aFx44mglAbs&maxResults=50&key=[YOUR_API_KEY] HTTP/1.1

    
# get all videos by channel_id
GET https://youtube.googleapis.com/youtube/v3/search?part=snippet&channelId={channelId}&key={API_KEY}
